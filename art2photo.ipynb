# %%
import os
import glob
from IPython.display import Image

# %%
art2photo_dir = "/home/x/pytorch-CycleGAN-and-pix2pix/datasets/art2photo/"
results_dir = "/home/x/pytorch-CycleGAN-and-pix2pix/checkpoints/art2photo_cyclegan/web/images"

# %%
for subdir in glob.glob(art2photo_dir+"*/"):
    for image in glob.glob(subdir+"*.jpg"):
        print(image)
        display(Image(image))
        break
# Out:
# /home/x/pytorch-CycleGAN-and-pix2pix/datasets/art2photo/testB/vangogh_2015-04-06 08:00:28.jpg
# /home/x/pytorch-CycleGAN-and-pix2pix/datasets/art2photo/testA/monet_01020.jpg
# /home/x/pytorch-CycleGAN-and-pix2pix/datasets/art2photo/trainB/monet_2014-05-06 03:35:48.jpg
# /home/x/pytorch-CycleGAN-and-pix2pix/datasets/art2photo/trainA/ukiyoe_00620.jpg

# %%
os.chdir(results_dir)
for file in glob.glob("*.png"):
    print(file)
    display(Image(file))
# Out:
# epoch001_rec_B.png
# epoch001_real_B.png
# epoch001_idt_B.png
# epoch001_idt_A.png
# epoch001_fake_A.png
# epoch001_rec_A.png
# epoch001_real_A.png
# epoch001_fake_B.png
